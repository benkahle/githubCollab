ieparsley', u'samccone', u'alexeypro', u'fge', u'runnedrun', u'slacs', u'nrubin', u'pingles', u'llasram', u'mstump', u'yuhanonescreen', u'adamwight', u'asmundg', u'powdahound', u'nelhage', u'cwjohnston', u'derek9gag', u'anderiv', u'mikemead', u'rubayeet', u'pior', u'dant24', u'wlp1979', u'snoldak924', u'asgh', u'drob', u'bdarfler', u'Bilzac', u'arikfr', u'drewrothstein', u'Gestas', u'gammons', u'ianneub', u'jankob', u'mertonium', u'jrbasso', u'miketheman', u'electronym', u'skyzyx', u'tplesnar', u'zsiddique', u'craigglennie'], u'amonmillner': [u'sarahwalters', u'hboortz', u'sihrc', u'JiayingWei', u'AllenDowney', u'paulruvolo', u'adgarrett', u'yunhsincynthiachen', u'mmahlenk', u'JLangowitz', u'aloverso', u'bminch', u'Brooks-Willis', u'CharlieMouton', u'ETumang', u'upsidebracelet', u'hpelletier', u'hhansson', u'amuthaOlin', u'juliebarron', u'JPWS2013', u'maorbernstein', u'morganzhu', u'segerphilip', u'rileychapman', u'skumarasena', u'srli', u'sgrim3', u'tchoetso', u'dinopants174'], u'Greenlightrj': [u'meghanrosetighe', u'SeanCCarter', u'matthewruehle', u'adority', u'paulruvolo', u'benthill', u'Cazatron', u'BlitzzFalke', u'gabrielecirulli', u'marg51', u'TimPetricola', u'leereilly', u'rayhaanj', u'ghoullier', u'david-risney', u'coding46', u'iharosi', u'chrisprice', u'jimminning', u'johankj', u'maciejczyzewski', u'marcingajda', u'mfrederiksen', u'Mechazawa', u'remram44', u'codeKonami'], u'tcr': [u'kyleburnett', u'AerialX', u'mathiasbynens', u'rmathew1992', u'asjchae', u'dscape', u'jwarkentin', u'mgh', u'mikehenrty', u'CarlQLange', u'chris-gc', u'alexcrichton', u'bors', u'wycats', u'carllerche', u'tilde-engineering', u'tomaka', u'brson', u'geomaster', u'bkoropoff', u'steveklabnik', u'huonw', u'mbrubeck', u'EduardoBautista', u'halorgium', u'jdeseno', u'dotdash', u'suhr', u'ebfe ...

# %%
def bfs(graph, start, end):
    # maintain a queue of paths
    queue = []
    # push the first path into the queue
    queue.append([start])
    while queue:
        # get the first path from the queue
        path = queue.pop(0)
        # get the last node from the path
        node = path[-1]
        # path found
        if node == end:
            return path
        # enumerate all adjacent nodes, construct a new path and push it into the queue
        for adjacent in graph.get(node, []):
            new_path = list(path)
            new_path.append(adjacent)
            queue.append(new_path)

hashlist = bfs(data, 'greenteawarrior', 'aloverso')
for i in hashlist: #hashlist is the bfs output
    print i
# Out:
# greenteawarrior
# corydolphin
# AllenDowney
# aloverso
